# %% [markdown]
# # Task 2
#
# ## General instructions
#
# First, update the following cell to have a link to your Homework 1 GitHub repository
#
# **UPDATE THIS LINK**
# https://github.com/kateebeckerr/eds220-hwk-2
#
# Add comments for all your code and commit as needed. Err on the side of commenting and commiting too much for now.
#
#
# ## About the data
#
# In this task you will use [Air Quality Index (AQI)](https://www.airnow.gov/aqi/aqi-basics/) data from the [US Environmental Protection Agency](https://www.epa.gov) to visualize the impact on the AQI of the 2017 [Thomas Fire](https://en.wikipedia.org/wiki/Thomas_Fire) in Santa Barbara County.

# %% [markdown]
# ## FINAL CODE
#
# You will use the next cell at the end of the task. Leave it blank for now.

# %%
### ===== FINAL CODE =====

#imported the required packages
#import pandas as pd
#import numpy as np 

#read in aqi 2017 data and stored it as aqi_2107
#aqi_2017 = pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_county_2017.zip')
#aqi_2017

#read in aqi 2018 data and stored it as aqi_2018
#aqi_2018 = pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_county_2018.zip')
#aqi_2018

# .head dispays the first 5 rows of each df 
#aqi_2018.head
#aqi_2017.head

#examines the types of each df, both are pd.dataframes 
#type(aqi_2017)
#type(aqi_2018)

#counts the number of missing (NA) values in each column of the aqi_2017 and aqi_2018 mdf 
#aqi_2017.isna().sum()
#aqi_2018.isna().sum()

#extracts a summary of each df including the total number of rows and columns 
#aqi_2017.info()
#aqi_2018.info()

#.shape returns the dimensions of each df including the number of rows and columns 
#aqi_2017.shape 
#aqi_2018.shape 

#combined the aqi2017 and aqi2018 df in which the indices are glued together and calls it aqi
#aqi = pd.concat([aqi_2017, aqi_2018])

#aqi.shape #checks dimensions to see if function worked 

# initial column names: notice caps and spaces (difficult to work with!)
#print(aqi.columns, '\n')

# re-assign the column names - .str.lower() makes them lower case
#aqi.columns = aqi.columns.str.lower()
#print(aqi.columns, '\n')

#  re-assign the column names again - .str.replace(' ','_') replaces the space for _
#aqi.columns = aqi.columns.str.replace(' ','_')
#print(aqi.columns)

#creates a new dataframe, aqi_sb, with data from county = santa barbara only by indexing in the county_name column for a "santa barbara" row
#aqi_sb = aqi.loc[aqi.county_name == "Santa Barbara"] 

#aqi_sb.head #returns first five 5 rows of the df

#drops state_name, county_name, state_code, and county_code columns from aqi_sb df
#aqi_sb = aqi_sb.drop(columns = ['state_name', 'county_name', 'state_code', 'county_code']) #drops these columns from dataframe 

#aqi_sb.dtypes #checks datatypes of columns, the data column is an object but it should be a data time object

#converts the date column in the aqi_sb df to datetime format 
#aqi_sb.date = pd.to_datetime(aqi_sb.date)

#set date column as the index of the df
#aqi_sb = aqi_sb.set_index('date')


#creates a pd.Series, five_day_average, which calcualted a rolling or moving average of the data in the aqi_sb df over a 5 day window
#five_day_average = aqi_sb.rolling('5D').mean()

aqi_sb.plot(x = 'date',  #creates a line plot with date on the x axis  
        y =['aqi', 'five_day_average'], #plots aqi and five_day average on the same plot 
        title = 'Air Quality Index Since 2017 Thomas Fires', #creates a title
        xlabel='Date', #creates an x label
        ylabel='Air Quality Index (AQI)',  #creates the y label       
        color = {'aqi':'#d73110', #sets the colors of each line 
                 'five_day_average': '#56a4e8'
                 }
        )
# Out:
# <AxesSubplot:title={'center':'Air Quality Index Since 2017 Thomas Fires'}, xlabel='Date', ylabel='Air Quality Index (AQI)'>

# %% [markdown]
# ## 1
#
# 1. Go to [EPA's website on Air Quality Data Collected at Outdoor Monitors Across the US](https://www.epa.gov/outdoor-air-quality-data).
# 2. Under "Donwload Data" click on "Pre-generated Data Files"
# 3. Click on "Tables of Daily AQI"
# 4. Copy the URL to the 2017 Daily AQI **by County** zip file `daily_aqi_by_county_2017.zip`
# 5. In the next code cell read in the data from the URL using the `pd.read_csv` function and store it as `aqi_17`.
# 6. In the same cell, read in the data for the 2018 Daily AQI by County zip file and store it as `aqi_18`.

# %%
# solve exercise here
#import packages
import pandas as pd
import numpy as np 

#read in data 
aqi_2017 = pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_county_2017.zip')
aqi_2017

aqi_2018 = pd.read_csv('https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_county_2018.zip')
aqi_2018
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2018-01-02   32
# 1         Alabama     Baldwin           1            3  2018-01-05   34
# 2         Alabama     Baldwin           1            3  2018-01-08   15
# 3         Alabama     Baldwin           1            3  2018-01-11   19
# 4         Alabama     Baldwin           1            3  2018-01-14   25
# ...           ...         ...         ...          ...         ...  ...
# 327532    Wyoming      Weston          56           45  2018-12-27   36
# 327533    Wyoming      Weston          56           45  2018-12-28   35
# 327534    Wyoming      Weston          56           45  2018-12-29   35
# 327535    Wyoming      Weston          56           45  2018-12-30   31
# 327536    Wyoming      Weston          56           45  2018-12-31   35
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %% [markdown]
# ## 2
# (a) and (b) Use the next two cells to look at the head of both data frames.
#
# (c) Use this cell to make some other preliminary data exploration of your choosing.

# %%
# (a)
aqi_2018.head
# Out:
# <bound method NDFrame.head of        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2018-01-02   32
# 1         Alabama     Baldwin           1            3  2018-01-05   34
# 2         Alabama     Baldwin           1            3  2018-01-08   15
# 3         Alabama     Baldwin           1            3  2018-01-11   19
# 4         Alabama     Baldwin           1            3  2018-01-14   25
# ...           ...         ...         ...          ...         ...  ...
# 327532    Wyoming      Weston          56           45  2018-12-27   36
# 327533    Wyoming      Weston          56           45  2018-12-28   35
# 327534    Wyoming      Weston          56           45  2018-12-29   35
# 327535    Wyoming      Weston          56           45  2018-12-30   31
# 327536    Wyoming      Weston          56           45  2018-12-31   35
#
# ...

# %%
# (b)
#used head to briefly explore the dataframe and its contents 
aqi_2017.head
# Out:
# <bound method NDFrame.head of        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2017-01-01   21
# 1         Alabama     Baldwin           1            3  2017-01-04   22
# 2         Alabama     Baldwin           1            3  2017-01-10   19
# 3         Alabama     Baldwin           1            3  2017-01-13   30
# 4         Alabama     Baldwin           1            3  2017-01-16   16
# ...           ...         ...         ...          ...         ...  ...
# 326796    Wyoming      Weston          56           45  2017-12-27   39
# 326797    Wyoming      Weston          56           45  2017-12-28   36
# 326798    Wyoming      Weston          56           45  2017-12-29   31
# 326799    Wyoming      Weston          56           45  2017-12-30   31
# 326800    Wyoming      Weston          56           45  2017-12-31   26
#
# ...

# %%
# (c) 
#both are pd.dataframes 
type(aqi_2017)
type(aqi_2018)
# Out:
# pandas.core.frame.DataFrame

# %%
#there ar zero NA values in each dataframe 
aqi_2017.isna().sum()
aqi_2018.isna().sum()
# Out:
# State Name                   0
# county Name                  0
# State Code                   0
# County Code                  0
# Date                         0
# AQI                          0
# Category                     0
# Defining Parameter           0
# Defining Site                0
# Number of Sites Reporting    0
# dtype: int64

# %%
#used info to extract total number of rows and columns 
aqi_2017.info()
aqi_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326801 entries, 0 to 326800
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State Name                 326801 non-null  object
#  1   county Name                326801 non-null  object
#  2   State Code                 326801 non-null  int64
#  3   County Code                326801 non-null  int64
#  4   Date                       326801 non-null  object
#  5   AQI                        326801 non-null  int64
#  6   Category                   326801 non-null  object
#  7   Defining Parameter         326801 non-null  object
#  8   Defining Site              326801 non-null  object
#  9   Number of Sites Reporting  326801 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 24.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327537 entries, 0 to 327536
# Data columns (total 10 columns):
# ...

# %%
#used shape holding number of rows followed by number of colummns, 327537 x 10 for both 
aqi_2017.shape 
aqi_2018.shape
# Out:
# (327537, 10)

# %% [markdown]
# ## 3
# We currently have two separate dataframes. For this exercise we will need to "glue" them one on top of the other. The pandas function `pd.concat()` can achieve this.
#
# Pass `[aqi_17, aqi_18]` as the input of `pd.concat()` and store the output as  `aqi`.
# In the next line run `aqi`.
#
# 👀 NOTE: When we concatenate like this, without any extra parameters for `pd.concat()` the indices for the two dataframes are just "glued together", the index of the resulting dataframe is not updated to start from 0. Notice the index of `aqi` ends in 327536 while it has 654338 rows.

# %%
# solve exercise here
aqi = pd.concat([aqi_2017, aqi_2018]) #combining the two dataframe , indices are glued together
aqi.shape
#10 columns and 654338 rows, the concat worked
# Out:
# (654338, 10)

# %%
aqi

# %% [markdown]
# ## 4
#
# Run the follwoing cell and read the comments to understand how the column names are being updated.

# %%
# initial column names: notice caps and spaces (difficult to work with!)
print(aqi.columns, '\n')

# re-assign the column names - .str.lower() makes them lower case
aqi.columns = aqi.columns.str.lower()
print(aqi.columns, '\n')

#  re-assign the column names again - .str.replace(' ','_') replaces the space for _
aqi.columns = aqi.columns.str.replace(' ','_')
print(aqi.columns)

# as a "one liner" you could achieve this column name cleaning like this:
# aqi.columns = aqi.columns.str.lower().str.replace(' ','_')

aqi
# Out:
# Index(['State Name', 'county Name', 'State Code', 'County Code', 'Date', 'AQI',
#        'Category', 'Defining Parameter', 'Defining Site',
#        'Number of Sites Reporting'],
#       dtype='object')
#
# Index(['state name', 'county name', 'state code', 'county code', 'date', 'aqi',
#        'category', 'defining parameter', 'defining site',
#        'number of sites reporting'],
#       dtype='object')
#
# Index(['state_name', 'county_name', 'state_code', 'county_code', 'date', 'aqi',
#        'category', 'defining_parameter', 'defining_site',
#        'number_of_sites_reporting'],
#       dtype='object')
#        state_name county_name  state_code  county_code        date  aqi  \
# 0         Alabama     Baldwin           1            3  2017-01-01   21
# 1         Alabama     Baldwin           1            3  2017-01-04   22
# 2         Alabama     Baldwin           1            3  2017-01-10   19
# 3         Alabama     Baldwin           1            3  2017-01-13   30
# ...

# %% [markdown]
# ## 5
# In the next cell:
# - Select only data from `Santa Barbara` county and store in a new variable `aqi_sb`.
# - Remove the `state_name`, `county_name`, `state_code` and `county_code` columns from `aqi_sb`.
# - Use the `dtypes` attribute to check the data types of the columns. What do you notice for the date column?

# %%
# solve exercise here

#aqi_sb = aqi[(aqi['county_name'] == "santa_barbara") & (df['price'] == '100')]

aqi_sb = aqi.loc[aqi.county_name == "Santa Barbara"] #creates a new dataframe, aqi_sb, with data from county = santa barbara only 
aqi_sb.head
aqi_sb = aqi_sb.drop(columns = ['state_name', 'county_name', 'state_code', 'county_code']) #drops these columns from dataframe 
aqi_sb.dtypes #checks datatypes of coulmns, the data column is an object but it should be a data time object

aqi_sb
# Out:
#              date  aqi  category defining_parameter defining_site  \
# 28648  2017-01-01   39      Good              Ozone   06-083-4003
# 28649  2017-01-02   36      Good              Ozone   06-083-4003
# 28650  2017-01-03   71  Moderate               PM10   06-083-4003
# 28651  2017-01-04   34      Good              Ozone   06-083-4003
# 28652  2017-01-05   37      Good              Ozone   06-083-4003
# ...           ...  ...       ...                ...           ...
# 29128  2018-12-27   37      Good              Ozone   06-083-1025
# 29129  2018-12-28   39      Good              Ozone   06-083-1021
# 29130  2018-12-29   39      Good              Ozone   06-083-1021
# 29131  2018-12-30   39      Good              Ozone   06-083-1021
# 29132  2018-12-31   38      Good              Ozone   06-083-1021
#
#        number_of_sites_reporting
# 28648                         12
# 28649                         11
# 28650                         12
# 28651                         13
# ...

# %% [markdown]
# ## 6
# In the next cell:
# 1. Update the date column of `aqi_sb` to be a datetime object.
# 2. Update the index of `aqi_sb` to be the date column.

# %%
# solve exercise here
aqi_sb.date = pd.to_datetime(aqi_sb.date)

#converted data columns to datetime64 type
aqi_sb = aqi_sb.set_index('date')

# %% [markdown]
# ## 7
# In the next cell, check that you've updated the index by accessing the index of `aqi_sb`  by running `aqi_sb.index`. Add in a comment what is the data type (dtype) of the index.

# %%
# solve exercise here
aqi_sb.index #checked the dtype of the index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', name='date', length=730, freq=None)

# %% [markdown]
# The dtype of the index is a datetime64

# %% [markdown]
# ## 8
# Run the next cell and read through the comments. They will explain how to do make an average over a rolling window.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.rolling.html

# %%
# rolling() is a method for pandas.series that provides rolling window calculations
# the parameter '5D' indicates we want the window to be 5 days
# This is a lazy method (think groupby), we need to specify what we want to calculate over each window
# here we add the aggregator function mean()
# this indicates we want the mean over each window
# and we get a pd.Series as ouput

five_day_average = aqi_sb.rolling('5D').mean()
five_day_average
# Out:
# /tmp/ipykernel_1647250/135637345.py:8: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['category', 'defining_parameter', 'defining_site'], dtype='object')
#   five_day_average = aqi_sb.rolling('5D').mean()
#                   aqi  number_of_sites_reporting
# date
# 2017-01-01  39.000000                  12.000000
# 2017-01-02  37.500000                  11.500000
# 2017-01-03  48.666667                  11.666667
# 2017-01-04  45.000000                  12.000000
# 2017-01-05  43.400000                  12.000000
# ...               ...                        ...
# 2018-12-27  38.600000                  11.600000
# 2018-12-28  38.600000                  11.600000
# 2018-12-29  38.200000                  11.800000
# 2018-12-30  37.800000                  11.800000
# 2018-12-31  38.400000                  11.800000
#
# ...

# %% [markdown]
# ## 9
#
# Without creating any new variables, add the mean of the AQI over a 5-day rolling window as a new column named 'five_day_average' to the `aqi_sb` dataframe.

# %%
# solve exercise here

aqi_sb['five_day_average'] = aqi_sb['aqi'].rolling('5D').mean()

aqi_sb
# Out:
#             aqi  category defining_parameter defining_site  \
# date
# 2017-01-01   39      Good              Ozone   06-083-4003
# 2017-01-02   36      Good              Ozone   06-083-4003
# 2017-01-03   71  Moderate               PM10   06-083-4003
# 2017-01-04   34      Good              Ozone   06-083-4003
# 2017-01-05   37      Good              Ozone   06-083-4003
# ...         ...       ...                ...           ...
# 2018-12-27   37      Good              Ozone   06-083-1025
# 2018-12-28   39      Good              Ozone   06-083-1021
# 2018-12-29   39      Good              Ozone   06-083-1021
# 2018-12-30   39      Good              Ozone   06-083-1021
# 2018-12-31   38      Good              Ozone   06-083-1021
#
#             number_of_sites_reporting  five_day_average
# date
# 2017-01-01                         12         39.000000
# 2017-01-02                         11         37.500000
# 2017-01-03                         12         48.666667
# ...

# %% [markdown]
# ## 10
# Make a line plot showing both the daily AQI and the 5-day average (5-day average on top of the AQI). Update the title and colors of the graph. Can you see the AQI going up during the Thomas Fire in December 2017?

# %%
aqi_sb.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', name='date', length=730, freq=None)

# %%
# solve exercise here
#aqi_sb = aqi_sb.reset_index()

aqi_sb.plot(x = 'date', 
        y =['aqi', 'five_day_average'],
        title = 'Air Quality Index Since 2017 Thomas Fires',
        xlabel='Date',
        ylabel='Air Quality Index (AQI)',        
        color = {'aqi':'#d73110',
                 'five_day_average': '#56a4e8'
                 }
        )
# Out:
# <AxesSubplot:title={'center':'Air Quality Index Since 2017 Thomas Fires'}, xlabel='Date', ylabel='Air Quality Index (AQI)'>

# %% [markdown]
# ## 11
#
# Collect all the relevant code into the first blank cell of the notebook titled "FINAL CODE". This single cell will have the end-to-end workflow: from importing libraries and loading the data, to producing the graph. The *only* ouput of this cell should be the graph you produced in the previous exercise. For each line, add a single comment explaining what the code does.
